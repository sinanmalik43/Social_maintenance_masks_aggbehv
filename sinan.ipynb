# %%
import seaborn as sns
import pandas as pd

# Prepare data
df = pd.DataFrame({
    'CNTRL': cntrl,
    'HGRY': hgry
})

# Create joint plot with regression line
sns.jointplot(x='CNTRL', y='HGRY', data=df, kind='reg', color='blue', marginal_kws=dict(bins=25, fill=True))

# Customize plot
plt.suptitle('Joint Plot with Regression Line of CNTRL and HGRY', y=1.02)

# Display the plot
plt.show()

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Example DataFrame setup
data = {
    'Parallel_Index_CNTRL': [0.69, 0.86, 0.73, 0.74, 0.75, 0.73, 0.74, 0.73, 0.80, 0.79,
                             0.70, 0.76, 0.75, 0.80, 0.71, 0.82, 0.79, 0.68, 0.77, 0.68],
    'Parallel_Index_HGRY': [0.76, 0.83, 0.68, 0.74, 0.83, 0.84, 0.82, 0.76, 0.84, 0.77,
                            0.79, 0.78, 0.79, 0.80, 0.76, 0.72, 0.72, 0.78, 0.77, 0.79]
}
df = pd.DataFrame(data)

# Sort data for cumulative probability calculation
df_sorted_cntrl = df.sort_values(by='Parallel_Index_CNTRL')
df_sorted_hgry = df.sort_values(by='Parallel_Index_HGRY')

# Calculate cumulative probability for control and hungry conditions
df_sorted_cntrl['Cumulative_Probability_CNTRL'] = np.arange(1, len(df_sorted_cntrl) + 1) / len(df_sorted_cntrl)
df_sorted_hgry['Cumulative_Probability_HGRY'] = np.arange(1, len(df_sorted_hgry) + 1) / len(df_sorted_hgry)

# Plot cumulative probability against Parallel Index for both conditions
plt.figure(figsize=(10, 6))
plt.plot(df_sorted_cntrl['Parallel_Index_CNTRL'], df_sorted_cntrl['Cumulative_Probability_CNTRL'], 
         marker='o', linestyle='-', label='Control')
plt.plot(df_sorted_hgry['Parallel_Index_HGRY'], df_sorted_hgry['Cumulative_Probability_HGRY'], 
         marker='o', linestyle='-', label='Hungry')

plt.title('Cumulative Probability vs. Parallel Index (Control vs Hungry)')
plt.xlabel('Parallel Index')
plt.ylabel('Cumulative Probability')
plt.legend()
plt.show()

# %%
import numpy as np
import imageio.v3 as iio
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

# Define paths
input_path = '/Users/sinan/Downloads/images.jpeg'  # Update this path based on your actual path
output_path = '/Users/sinan/Downloads/heatmap.png'  # Path where the heatmap will be saved

# Load image
image = iio.imread(input_path)

# Convert image to grayscale if it's not already
if len(image.shape) == 3:  # If image has multiple channels (e.g., RGB)
    image = np.mean(image, axis=2)  # Convert to grayscale by averaging channels

# Normalize image to range [0, 1]
image = image / np.max(image)

# Apply Gaussian filter to smooth the image (optional, depending on your needs)
smooth_image = gaussian_filter(image, sigma=2)

# Generate the heatmap
plt.imshow(smooth_image, cmap='hot', interpolation='nearest')
plt.colorbar()  # Show color scale

# Save the heatmap
plt.savefig(output_path, bbox_inches='tight', pad_inches=0.1, dpi=300)
plt.show()

# %%
import numpy as np
import imageio.v3 as iio
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

# Define paths
input_path = '/Users/sinan/Downloads/HE.png'  # Update this path based on your actual path
output_path = '/Users/sinan/Downloads/HExp_Beh_Hm.png'  # Path where the heatmap will be saved

# Load image
image = iio.imread(input_path)

# Convert image to grayscale if it's not already
if len(image.shape) == 3:  # If image has multiple channels (e.g., RGB)
    image = np.mean(image, axis=2)  # Convert to grayscale by averaging channels

# Normalize image to range [0, 1]
image = image / np.max(image)

# Apply Gaussian filter to smooth the image (optional, depending on your needs)
smooth_image = gaussian_filter(image, sigma=2)

# Generate the heatmap
plt.imshow(smooth_image, cmap='jet', interpolation='nearest')
plt.colorbar()  # Show color scale

#save and show the figure with high resolution (format="png", dpi=2000)

# Save the heatmap
plt.savefig(output_path, bbox_inches='tight', pad_inches=0.1, dpi=300)
plt.show()

# %%
import numpy as np
import imageio.v3 as iio
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

# Define paths
input_path = '/Users/sinan/Downloads/CE.png'  # Update this path based on your actual path
output_path = '/Users/sinan/Downloads/CExp_Beh_Hm.png'  # Path where the heatmap will be saved

# Load image
image = iio.imread(input_path)

# Convert image to grayscale if it's not already
if len(image.shape) == 3:  # If image has multiple channels (e.g., RGB)
    image = np.mean(image, axis=2)  # Convert to grayscale by averaging channels

# Normalize image to range [0, 1]
image = image / np.max(image)

# Apply Gaussian filter to smooth the image (optional, depending on your needs)
smooth_image = gaussian_filter(image, sigma=2)

# Generate the heatmap
plt.imshow(smooth_image, cmap='jet', interpolation='bilinear')
plt.colorbar()  # Show color scale

#save and show the figure with high resolution (format="png", dpi=2000)

# Save the heatmap
plt.savefig(output_path, bbox_inches='tight', pad_inches=0.1, dpi=300)
plt.show()

# %%
import numpy as np
import imageio.v3 as iio
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

# Define paths
input_path = '/Users/sinan/Downloads/CMB.png'  # Update this path based on your actual path
output_path = '/Users/sinan/Downloads/CMB_Agg_Beh_Hm.png'  # Path where the heatmap will be saved

# Load image
image = iio.imread(input_path)

# Convert image to grayscale if it's not already
if len(image.shape) == 3:  # If image has multiple channels (e.g., RGB)
    image = np.mean(image, axis=2)  # Convert to grayscale by averaging channels

# Normalize image to range [0, 1]
image = image / np.max(image)

# Apply Gaussian filter to smooth the image (optional, depending on your needs)
smooth_image = gaussian_filter(image, sigma=3)

# Generate the heatmap
plt.imshow(smooth_image, cmap='jet', interpolation='bilinear')
plt.colorbar()  # Show color scale

# Save the heatmap
plt.savefig(output_path, bbox_inches='tight', pad_inches=0.1, dpi=600) 
plt.show()

# %%
import numpy as np
import imageio.v3 as iio
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

# Define paths
input_path = '/Users/sinan/Downloads/HMB.png'  # Update this path based on your actual path
output_path = '/Users/sinan/Downloads/HMB_Agg_Beh_Hm.png'  # Path where the heatmap will be saved

# Load image
image = iio.imread(input_path)

# Convert image to grayscale if it's not already
if len(image.shape) == 3:  # If image has multiple channels (e.g., RGB)
    image = np.mean(image, axis=2)  # Convert to grayscale by averaging channels

# Normalize image to range [0, 1]
image = image / np.max(image)

# Apply Gaussian filter to smooth the image (optional, depending on your needs)
smooth_image = gaussian_filter(image, sigma=3)

# Generate the heatmap
plt.imshow(smooth_image, cmap='jet', interpolation='bilinear')
plt.colorbar()  # Show color scale

# Save the heatmap
plt.savefig(output_path, bbox_inches='tight', pad_inches=0.1, dpi=600) 
plt.show()

# %%
import numpy as np
import imageio.v3 as iio
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

# Define paths
input_path = '/Users/sinan/Downloads/HMB.png'  # Update this path based on your actual path
output_path = '/Users/sinan/Downloads/HMB_Agg_Beh_Hm.png'  # Path where the heatmap will be saved

# Load image
image = iio.imread(input_path)

# Convert image to grayscale if it's not already
if len(image.shape) == 3:  # If image has multiple channels (e.g., RGB)
    image = np.mean(image, axis=2)  # Convert to grayscale by averaging channels

# Normalize image to range [0, 1]
image = image / np.max(image)

# Apply Gaussian filter to smooth the image (optional, depending on your needs)
smooth_image = gaussian_filter(image, sigma=3.5)

# Create a figure with specified size
plt.figure(figsize=(6.4, 4.8))

# Generate the heatmap without color bar or axes
plt.imshow(smooth_image, cmap='gnuplot2', interpolation='bilinear')
plt.axis('off')  # Turn off the axis

# Save the heatmap
plt.savefig(output_path, bbox_inches='tight', pad_inches=0.1, dpi=600, transparent=False) 
plt.show()

# %%
import numpy as np
import imageio.v3 as iio
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

# Define paths
input_path = '/Users/sinan/Downloads/CMB.png'  # Update this path based on your actual path
output_path = '/Users/sinan/Downloads/CMB_Agg_Beh_Hm.png'  # Path where the heatmap will be saved

# Load image
image = iio.imread(input_path)

# Convert image to grayscale if it's not already
if len(image.shape) == 3:  # If image has multiple channels (e.g., RGB)
    image = np.mean(image, axis=2)  # Convert to grayscale by averaging channels

# Normalize image to range [0, 1]
image = image / np.max(image)

# Apply Gaussian filter to smooth the image (optional, depending on your needs)
smooth_image = gaussian_filter(image, sigma=3.4)

# Create a figure with specified size
plt.figure(figsize=(6.4, 4.8))

# Generate the heatmap without color bar or axes
plt.imshow(smooth_image, cmap='gnuplot2', interpolation='bilinear')
plt.axis('off')  # Turn off the axis

# Save the heatmap
plt.savefig(output_path, bbox_inches='tight', pad_inches=0.1, dpi=600, transparent=False) 
plt.show()

# %%
E762EE9D0E1

# %%
import numpy as np
import imageio.v3 as iio
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

# Define paths
input_path = '/Users/sinan/Downloads/HMB.png'  # Update this path based on your actual path
output_path = '/Users/sinan/Downloads/HMB_Agg_Beh_1_Hm.png'  # Path where the heatmap will be saved

# Load image
image = iio.imread(input_path)

# Convert image to grayscale if it's not already
if len(image.shape) == 3:  # If image has multiple channels (e.g., RGB)
    image = np.mean(image, axis=2)  # Convert to grayscale by averaging channels

# Normalize image to range [0, 1]
image = image / np.max(image)

# Apply Gaussian filter to smooth the image (optional, depending on your needs)
smooth_image = gaussian_filter(image, sigma=3.5)

# Create a figure with specified size
plt.figure(figsize=(6.4, 4.8))

# Generate the heatmap without color bar or axes
plt.imshow(smooth_image, cmap='jet', interpolation='bilinear')
plt.axis('off')  # Turn off the axis

# Save the heatmap
plt.savefig(output_path, bbox_inches='tight', pad_inches=0.1, dpi=600, transparent=False) 
plt.show()

# %%
import numpy as np
import imageio.v3 as iio
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

# Define paths
input_path = '/Users/sinan/Downloads/CMB.png'  # Update this path based on your actual path
output_path = '/Users/sinan/Downloads/CMB_Agg_Beh_1_Hm.png'  # Path where the heatmap will be saved

# Load image
image = iio.imread(input_path)

# Convert image to grayscale if it's not already
if len(image.shape) == 3:  # If image has multiple channels (e.g., RGB)
    image = np.mean(image, axis=2)  # Convert to grayscale by averaging channels

# Normalize image to range [0, 1]
image = image / np.max(image)

# Apply Gaussian filter to smooth the image (optional, depending on your needs)
smooth_image = gaussian_filter(image, sigma=3)

# Create a figure with specified size
plt.figure(figsize=(6.4, 4.8))

# Generate the heatmap without color bar or axes
plt.imshow(smooth_image, cmap='jet', interpolation='bilinear')
plt.axis('off')  # Turn off the axis

# Save the heatmap
plt.savefig(output_path, bbox_inches='tight', pad_inches=0.1, dpi=600, transparent=False) 
plt.show()

# %%
import numpy as np
import imageio.v3 as iio
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

# Define paths
input_path = '/Users/sinan/Downloads/HE.png'  # Update this path based on your actual path
output_path = '/Users/sinan/Desktop/Ashil_24/HE_Exp_Hm.png'  # Path where the heatmap will be saved

# Load image
image = iio.imread(input_path)

# Convert image to grayscale if it's not already
if len(image.shape) == 3:  # If image has multiple channels (e.g., RGB)
    image = np.mean(image, axis=2)  # Convert to grayscale by averaging channels

# Normalize image to range [0, 1]
image = image / np.max(image)

# Apply Gaussian filter to smooth the image (optional, depending on your needs)
smooth_image = gaussian_filter(image, sigma=4)

# Create a figure with specified size
plt.figure(figsize=(6.4, 4.8))

# Generate the heatmap without color bar or axes
plt.imshow(smooth_image, cmap='gnuplot2', interpolation='bilinear')
plt.axis('off')  # Turn off the axis

# Save the heatmap
plt.savefig(output_path, bbox_inches='tight', pad_inches=0.1, dpi=600, transparent=False) 
plt.show()

# %%
import numpy as np
import imageio.v3 as iio
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

# Define paths
input_path = '/Users/sinan/Downloads/CE.png'  # Update this path based on your actual path
output_path = '/Users/sinan/Desktop/Ashil_24/CE_Exp_Hm.png'  # Path where the heatmap will be saved

# Load image
image = iio.imread(input_path)

# Convert image to grayscale if it's not already
if len(image.shape) == 3:  # If image has multiple channels (e.g., RGB)
    image = np.mean(image, axis=2)  # Convert to grayscale by averaging channels

# Normalize image to range [0, 1]
image = image / np.max(image)

# Apply Gaussian filter to smooth the image (optional, depending on your needs)
smooth_image = gaussian_filter(image, sigma=4)

# Create a figure with specified size
plt.figure(figsize=(6.4, 4.8))

# Generate the heatmap without color bar or axes
plt.imshow(smooth_image, cmap='gnuplot2', interpolation='bilinear')
plt.axis('off')  # Turn off the axis

# Save the heatmap
plt.savefig(output_path, bbox_inches='tight', pad_inches=0.1, dpi=600, transparent=False) 
plt.show()

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Generating sample data
np.random.seed(42)
groups = ['Drd1+', 'Drd2+', 'ChAT+', 'Other']
data = {
    'Group': np.repeat(groups, 100),
    'tdTomato mRNA': np.concatenate([
        np.random.beta(a=2, b=5, size=100),  # Drd1+
        np.random.beta(a=2, b=5, size=100),  # Drd2+
        np.random.beta(a=2.5, b=3, size=100),  # ChAT+
        np.random.beta(a=1.5, b=6, size=100),  # Other
    ])
}

df = pd.DataFrame(data)

# Create the plot
plt.figure(figsize=(8, 6))

# Boxplot to show the distribution
sns.boxplot(x='Group', y='tdTomato mRNA', data=df, 
            palette=['yellow', 'magenta', 'red', 'gray'], 
            width=0.6, fliersize=0, boxprops=dict(alpha=0.6))

# Overlay with a strip plot to show individual points
sns.stripplot(x='Group', y='tdTomato mRNA', data=df, 
              color='black', jitter=True, size=3)

# Customize plot
plt.title('tdTomato mRNA Expression Across Different Groups')
plt.ylabel('tdTomato mRNA (activity reporter)')
plt.xlabel('Groups')
plt.ylim(0, 1)
plt.tight_layout()

# Show plot
plt.show()
# Out:
# /var/folders/yv/_h8yc74n25xgwb58606g_n8r0000gn/T/ipykernel_11125/3125111228.py:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Group', y='tdTomato mRNA', data=df,

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Generating sample data
np.random.seed(42)
groups = ['Drd1+', 'Drd2+', 'ChAT+', 'Other']
data = {
    'Group': np.repeat(groups, 100),
    'tdTomato mRNA': np.concatenate([
        np.random.beta(a=2, b=5, size=100),  # Drd1+
        np.random.beta(a=2, b=5, size=100),  # Drd2+
        np.random.beta(a=2.5, b=3, size=100),  # ChAT+
        np.random.beta(a=1.5, b=6, size=100),  # Other
    ])
}

df = pd.DataFrame(data)

# Create the plot
plt.figure(figsize=(8, 6))

# Draw a boxplot on the left half
sns.boxplot(x='Group', y='tdTomato mRNA', data=df,
            palette=['yellow', 'magenta', 'red', 'gray'], 
            width=0.3, showcaps=False, boxprops={'facecolor':'None'}, 
            whiskerprops={'linewidth':0}, zorder=1)

# Create an offset for the strip plot to appear on the right half
for i, group in enumerate(groups):
    group_data = df[df['Group'] == group]['tdTomato mRNA']
    jittered_x = np.random.normal(i + 0.2, 0.02, size=len(group_data))  # right-side offset
    plt.scatter(jittered_x, group_data, color='black', zorder=2, s=10)

# Customize plot
plt.title('tdTomato mRNA Expression Across Different Groups')
plt.ylabel('tdTomato mRNA (activity reporter)')
plt.xlabel('Groups')
plt.ylim(0, 1)
plt.xticks(range(len(groups)), groups)
plt.tight_layout()

# Show plot
plt.show()
# Out:
# /var/folders/yv/_h8yc74n25xgwb58606g_n8r0000gn/T/ipykernel_11125/2201316490.py:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Group', y='tdTomato mRNA', data=df,

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Generating sample data
np.random.seed(42)
groups = ['Drd1+', 'Drd2+', 'ChAT+', 'Other']
data = {
    'Group': np.repeat(groups, 100),
    'tdTomato mRNA': np.concatenate([
        np.random.beta(a=2, b=5, size=100),  # Drd1+
        np.random.beta(a=2, b=5, size=100),  # Drd2+
        np.random.beta(a=2.5, b=3, size=100),  # ChAT+
        np.random.beta(a=1.5, b=6, size=100),  # Other
    ])
}

df = pd.DataFrame(data)

# Custom colors for each group
colors = ['yellow', 'magenta', 'red', 'gray']

# Calculate means and standard errors for error bars
means = df.groupby('Group')['tdTomato mRNA'].mean()
std_err = df.groupby('Group')['tdTomato mRNA'].std() / np.sqrt(100)

# Create the plot
plt.figure(figsize=(8, 6))

# Draw a boxplot on the left half
sns.boxplot(x='Group', y='tdTomato mRNA', data=df, width=0.2,
            palette=colors, showcaps=False, boxprops={'facecolor':'None'}, 
            whiskerprops={'linewidth':0}, zorder=1)

# Add error bars (mean ± standard error)
plt.errorbar(x=range(len(groups)), y=means, yerr=std_err, fmt='none', 
             ecolor='black', elinewidth=2, capsize=4, zorder=3)

# Create an offset for the strip plot to appear on the right half
for i, group in enumerate(groups):
    group_data = df[df['Group'] == group]['tdTomato mRNA']
    jittered_x = np.random.normal(i + 0.2, 0.02, size=len(group_data))  # right-side offset
    plt.scatter(jittered_x, group_data, color='black', zorder=2, s=10)

# Customize plot
plt.title('tdTomato mRNA Expression Across Different Groups')
plt.ylabel('tdTomato mRNA (activity reporter)')
plt.xlabel('Groups')
plt.ylim(0, 1)
plt.xticks(range(len(groups)), groups)
plt.tight_layout()

# Show plot
plt.show()
# Out:
# /var/folders/yv/_h8yc74n25xgwb58606g_n8r0000gn/T/ipykernel_11125/3007977472.py:32: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Group', y='tdTomato mRNA', data=df, width=0.2,

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Generating sample data
np.random.seed(42)
groups = ['Drd1+', 'Drd2+', 'ChAT+', 'Other']
data = {
    'Group': np.repeat(groups, 100),
    'tdTomato mRNA': np.concatenate([
        np.random.beta(a=2, b=5, size=100),  # Drd1+
        np.random.beta(a=2, b=5, size=100),  # Drd2+
        np.random.beta(a=2.5, b=3, size=100),  # ChAT+
        np.random.beta(a=1.5, b=6, size=100),  # Other
    ])
}

df = pd.DataFrame(data)

# Custom colors for each group
colors = ['yellow', 'magenta', 'red', 'gray']

# Create the plot
plt.figure(figsize=(6.4, 4.8))

# Draw a boxplot on the left half with whiskers as error bars
sns.boxplot(x='Group', y='tdTomato mRNA', data=df, width=0.2, palette=colors,
            showcaps=False, boxprops={'facecolor':'none'}, 
            whiskerprops={'color':'black', 'linewidth':1},  # Set whisker color and thickness
            flierprops={'marker': ''}, zorder=1)

# Create an offset for the strip plot to appear on the right half
for i, group in enumerate(groups):
    group_data = df[df['Group'] == group]['tdTomato mRNA']
    jittered_x = np.random.normal(i + 0.2, 0.02, size=len(group_data))  # right-side offset
    plt.scatter(jittered_x, group_data, color='red', zorder=2, s=10)

# Customize plot
plt.title('tdTomato mRNA Expression Across Different Groups')
plt.ylabel('tdTomato mRNA (activity reporter)')
plt.xlabel('Groups')
plt.ylim(0, 1)
plt.xticks(range(len(groups)), groups)
plt.tight_layout()

# Show plot
plt.show()
# Out:
# /var/folders/yv/_h8yc74n25xgwb58606g_n8r0000gn/T/ipykernel_5636/3929947019.py:28: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Group', y='tdTomato mRNA', data=df, width=0.2, palette=colors,

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# New dataset provided
data = {
    'Group': ['CNTRL'] * 20 + ['CNTRL + M'] * 20,  # Control and Control + M groups
    'tdTomato mRNA': [12, 21, 36, 28, 2, 6, 11, 42, 31, 38, 44, 34, 18, 22, 29, 1, 18, 22, 26, 0] + 
                     [263, 217, 131, 16, 212, 314, 237, 46, 372, 103, 164, 64, 151, 68, 158, 398, 167, 99, 275, 324]
}

df = pd.DataFrame(data)

# Custom colors for each group
colors = ['green', 'purple']  # Green for CNTRL, Purple for CNTRL + M

# Create the plot
plt.figure(figsize=(6.4, 4.8))

# Draw a boxplot on the left half with whiskers as error bars
sns.boxplot(x='Group', y='tdTomato mRNA', data=df, width=0.2, palette=colors,
            showcaps=False, boxprops={'facecolor':'none'}, 
            whiskerprops={'color':'black', 'linewidth':1},  # Set whisker color and thickness
            flierprops={'marker': ''}, zorder=1)

# Create an offset for the scatter plot to appear on the right half
groups = ['CNTRL', 'CNTRL + M']
for i, group in enumerate(groups):
    group_data = df[df['Group'] == group]['tdTomato mRNA']
    jittered_x = np.random.normal(i + 0.2, 0.02, size=len(group_data))  # right-side offset
    plt.scatter(jittered_x, group_data, color='red', zorder=2, s=10)

# Customize plot
plt.title('tdTomato mRNA Expression Across CNTRL and CNTRL + M Groups')
plt.ylabel('tdTomato mRNA (activity reporter)')
plt.xlabel('Groups')
plt.ylim(0, 450)
plt.xticks(range(len(groups)), groups)
plt.tight_layout()

# Show plot
plt.show()
# Out:
# /var/folders/yv/_h8yc74n25xgwb58606g_n8r0000gn/T/ipykernel_5636/1850049767.py:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Group', y='tdTomato mRNA', data=df, width=0.2, palette=colors,

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Generating sample data for tdTomato mRNA
np.random.seed(42)
groups = ['Drd1+', 'Drd2+', 'ChAT+', 'Other']
data = {
    'Group': np.repeat(groups, 100),
    'tdTomato mRNA': np.concatenate([
        np.random.beta(a=2, b=5, size=100),  # Drd1+
        np.random.beta(a=2, b=5, size=100),  # Drd2+
        np.random.beta(a=2.5, b=3, size=100),  # ChAT+
        np.random.beta(a=1.5, b=6, size=100),  # Other
    ])
}

df = pd.DataFrame(data)

# New data for time spent in the Mirror zone
mirror_zone_data = {
    'Group': ['CNTRL'] * 20 + ['CNTRL +M'] * 20 + ['HGRY'] * 20 + ['HGRY +M'] * 20,
    'Time in Mirror Zone': [
        153.93, 203.34, 178.72, 258.92, 263.32, 246.06, 177.07, 159.95, 180.73, 168.7,
        178.8, 195.15, 175.94, 176.75, 229.02, 204.95, 214.93, 246.37, 197.19, 219.21,
        243.49, 347.57, 184.45, 85.47, 192.88, 276.6, 339.82, 187.01, 322.57, 229.05,
        269.89, 155.61, 272.37, 220.76, 223.93, 360.01, 275.66, 275.73, 290.48, 332.6,
        200.83, 207.1, 172.65, 196.76, 187.65, 187.59, 178.57, 181.99, 192.56, 198,
        179.3, 196.61, 230.39, 223.39, 199.13, 218.08, 200.31, 175.57, 193.68, 159.99,
        345.02, 345.83, 359.93, 359.2, 325.14, 337.38, 282.46, 354.47, 359.11, 358.46,
        358.82, 359.22, 346.29, 310.35, 357.48, 360.03, 356.02, 351.11, 356.57, 360.02
    ]
}

df_mirror = pd.DataFrame(mirror_zone_data)

# Custom colors for the tdTomato mRNA groups
colors = ['yellow', 'magenta', 'red', 'gray']

# Create the first plot for tdTomato mRNA
plt.figure(figsize=(12, 6))

# Boxplot for tdTomato mRNA
plt.subplot(1, 2, 1)  # 1 row, 2 columns, first subplot
sns.boxplot(x='Group', y='tdTomato mRNA', data=df, width=0.2, palette=colors,
            showcaps=False, boxprops={'facecolor':'none'}, 
            whiskerprops={'color':'black', 'linewidth':1},
            flierprops={'marker': ''}, zorder=1)

# Strip plot for tdTomato mRNA
for i, group in enumerate(groups):
    group_data = df[df['Group'] == group]['tdTomato mRNA']
    jittered_x = np.random.normal(i + 0.2, 0.02, size=len(group_data))
    plt.scatter(jittered_x, group_data, color='red', zorder=2, s=10)

plt.title('tdTomato mRNA Expression Across Different Groups')
plt.ylabel('tdTomato mRNA (activity reporter)')
plt.xlabel('Groups')
plt.ylim(0, 1)
plt.xticks(range(len(groups)), groups)
plt.tight_layout()

# Create the second plot for time spent in the Mirror zone
plt.subplot(1, 2, 2)  # 1 row, 2 columns, second subplot
sns.boxplot(x='Group', y='Time in Mirror Zone', data=df_mirror, width=0.2,
            showcaps=False, boxprops={'facecolor':'none'}, 
            whiskerprops={'color':'black', 'linewidth':1},
            flierprops={'marker': ''}, zorder=1)

# Strip plot for time in Mirror zone
mirror_groups = df_mirror['Group'].unique()
for i, group in enumerate(mirror_groups):
    group_data = df_mirror[df_mirror['Group'] == group]['Time in Mirror Zone']
    jittered_x = np.random.normal(i + 0.2, 0.02, size=len(group_data))
    plt.scatter(jittered_x, group_data, color='blue', zorder=2, s=10)

plt.title()
plt.ylabel('Time Spent in the Mirror Zone [s]')
plt.xlabel('')
plt.xticks(range(len(mirror_groups)), mirror_groups)
plt.tight_layout()

# Show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 3
#       1 import numpy as np
#       2 import pandas as pd
# ----> 3 import seaborn as sns
#       4 import matplotlib.pyplot as plt
#       6 # Generating sample data for tdTomato mRNA
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/seaborn/__init__.py:9
#       7 from .categorical import *  # noqa: F401,F403
#       8 from .distributions import *  # noqa: F401,F403
# ----> 9 from .matrix import *  # noqa: F401,F403
#      10 from .miscplot import *  # noqa: F401,F403
#      11 from .axisgrid import *  # noqa: F401,F403
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/seaborn/matrix.py:13
#      10 import pandas as pd
#      11 from scipy.cluster import hierarchy
# ---> 13 from . import cm
#      14 from .axisgrid import Grid
# ...
